# %% [markdown]
# # Test Set Analysis
# ***Note**: The test set was initially constructed in the previous notebook, and additional examples were manually added afterward.*
#
# ## Importing Dependencies

# %%
import warnings

warnings.filterwarnings("ignore")

import pandas as pd

from toxicity_detector.utils.plotting import plot_category_distribution
from toxicity_detector.config.paths import UKR_PROCESSED
from toxicity_detector.config.labels import LABELS_EN

pd.set_option("display.max_colwidth", None)

# %% [markdown]
# ## Loading Data

# %%
test_df = pd.read_csv(UKR_PROCESSED["test"])
print("Test dataset:")
print(test_df.shape)
# Out:
# Test dataset:
# (1400, 8)

# %% [markdown]
# ## Quick Exploration

# %%
plot_category_distribution(test_df, LABELS_EN, title="Category Distribution in Test Set")

# %%
# Count of non-positively labeled comments
print("Number of non-positively labeled comments:", test_df[test_df[LABELS_EN].sum(axis=1) == 0].shape[0])
# Out:
# Number of non-positively labeled comments: 691
